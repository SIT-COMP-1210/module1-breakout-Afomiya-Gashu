# %% [markdown]
# <a href="https://colab.research.google.com/github/SIT-COMP-1210/module1-breakout-Afomiya-Gashu/blob/main/COMP1210_module1_breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SIT-COMP-1210/Module1-Breakout-@afomiya-Module1-Breakout-@afomiya-gashu.git
# Out:
# Cloning into 'Module1-{YourGitHubUser}'...
# remote: Repository not found.
# fatal: repository 'https://github.com/SIT-COMP-1210/Module1-{YourGitHubUser}.git/' not found

# %% [markdown]
# **Instructions**
#
#
# *   Replace "{YourGitHubUser}" with your GitHub username
# *   Run the cell above to clone this .ipynb file to your git repository
#
#
# *   Once you are done completing the assignment below, click on "File" above, from the dropdown select "Save a copy in GitHub"
# *   Edit the commit message to reflect your latest change (e.g "Submitting Breakout Session Assignment")
#
#
# *   Commit your change
#
#
# *   Lastly, go to GitHub Classroom repository to confirm your file submission

# %% [markdown]
# **Practice Problems**

# %% [markdown]
# 1) What is wrong with this code?
#
#
# *   print("Hello World)

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# 2. Print all the values below
#
# *   Hello Word
# *   3
# *  2+2

# %%
print("Hello World")
print('3')
print ("2+2")
# Out:
# Hello World
# 3
# 2+2

# %% [markdown]
# 3. Write a code that prints:
#
#
# *   Hello
#
#       Hello
#
#       Hello

# %%
print("Hello\n")
print("Hello\n")
print("Hello\n")
# Out:
# Hello
#
# Hello
#
# Hello

# %%
for i in range(3):
  print("Hello")
# Out:
# Hello
# Hello
# Hello

# %% [markdown]
# 4. Then combine it to 1 line:
#
#
# *   HelloHelloHello

# %%
print("Hello" *3)
# Out:
# HelloHelloHello

# %% [markdown]
# 5. What will be printed when you run:
#
#
#
#   *   print("2" + "2")
#   *   print(2 + 2)
#
#   *   print("A")
#   *   print("B")
#
#
#   *   print("A" + "B")

# %%
print("2" + "2")
print(2 + 2)
print("A")
print("B")
print("A" + "B")
# Out:
# 22
# 4
# A
# B
# AB
